# %%
# linear regression
# y = wx+b
import numpy as np
import matplotlib.pyplot as plt

alpha = 0.01
num_iters = 1500
x = np.array([[1, 1], [2, 2], [3, 3]])
w = np.zeros(num_iters+1)
b = np.zeros(num_iters+1)
# x = x + np.random.rand(3, 2)
N = len(x)
for i in range(1, num_iters+1):
    mw = 2/N * (np.sum((x[ :,0]**2)*w[i-1])+ np.sum(b[i-1]*x[ :,0]) - np.sum(x[ :,0]*x[ :,1]))
    mb = 2/N * (np.sum(w[i-1]*x[ :,0]) + N*b[i-1] - np.sum(x[ :,1]))
    w[i] = w[i-1] - alpha * mw
    b[i] = b[i-1] - alpha * mb
    print(w[i], b[i])
plt.plot(w, label='w')
plt.plot(b, label='b')
plt.legend()
plt.show()

plt.plot(x[ :,0], x[ :,1], 'ro')
plt.plot(x[ :,0], w[num_iters]*x[ :,0] + b[num_iters], label='predicted line')
# Out:
# 0.09333333333333332 0.04
# 0.17635555555555554 0.07546666666666667
# 0.25021037037037036 0.10690311111111112
# 0.3159146113580247 0.13475663407407407
# 0.3743723156016461 0.1594249169382716
# 0.42638723613462826 0.18126152597544032
# 0.472673966389712 0.2005808060105464
# 0.5138678306195836 0.21766223123474698
# 0.5505336771790326 0.2327542733852687
# 0.5831736963735787 0.24607784083040202
# 0.6122343710788286 0.25782933615885084
# 0.6381126563317839 0.2681833745925207
# 0.6611614734237833 0.2772952008473989
# 0.6816945945370009 0.2853028378934996
# 0.6999909855311408 0.2923289973541496
# 0.7162986669874016 0.29848277798582096
# 0.7308381469491446 0.3038611757466085
# 0.7438054728706934 0.30855042635371055
# 0.7553749450152802 0.3126271989118086
# 0.7657015288573817 0.31615965713296124
# 0.7749229998787077 0.31920840283600677
# 0.7831618504432547 0.32182731478413834
# 0.7905269851438521 0.3240642944707254
# 0.7971152280849302 0.3259619291755568
# ...

# %%
# linear regression
# y = wx+b
import numpy as np
import matplotlib.pyplot as plt

alpha = 0.01
num_iters = 1500
x = np.array([[1, 1], [2, 2], [3, 3]])
w = np.zeros(num_iters+1)
b = np.zeros(num_iters+1)
x = x + np.random.rand(3, 2)
N = len(x)
for i in range(1, num_iters+1):
    mw = 2/N * (np.sum((x[ :,0]**2)*w[i-1])+ np.sum(b[i-1]*x[ :,0]) - np.sum(x[ :,0]*x[ :,1]))
    mb = 2/N * (np.sum(w[i-1]*x[ :,0]) + N*b[i-1] - np.sum(x[ :,1]))
    w[i] = w[i-1] - alpha * mw
    b[i] = b[i-1] - alpha * mb
    print(w[i], b[i])
plt.plot(w, label='w')
plt.plot(b, label='b')
plt.legend()
plt.show()

plt.plot(x[ :,0], x[ :,1], 'ro')
plt.plot(x[ :,0], w[num_iters]*x[ :,0] + b[num_iters], label='predicted line')
# Out:
# 0.14591753738050958 0.050855721599258503
# 0.26708132630830256 0.0929433704075952
# 0.36769812248582007 0.12775319625496734
# 0.4512597590690322 0.15652218633652734
# 0.5206646451160496 0.18027710626306764
# 0.5783186158227267 0.19987022644376515
# 0.6262186436328652 0.2160089769020095
# 0.6660223229541352 0.22928056236470828
# 0.6991055462029264 0.24017239410799535
# 0.7266103780182038 0.24908904948615448
# 0.7494847934293756 0.2563663492511839
# 0.7685156626691675 0.26228304248384604
# 0.7843561303392645 0.2670705057138031
# 0.7975483415877814 0.2709207937100752
# 0.8085423060567327 0.273993322069368
# 0.817711555971239 0.2764204141231722
# 0.8253661431942514 0.2783119051684701
# 0.8317634274797853 0.27975896422642266
# 0.8371170313023263 0.2808372663072701
# 0.8416042728460221 0.28160962556051794
# 0.8453723357847892 0.28212818093096564
# 0.8485433905310575 0.2824362103705572
# 0.8512188451471884 0.28256963673162294
# 0.8534828738301831 0.28255827773912057
# ...
